# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('sd1.xlsx')

# %%
df = df.rename(columns={'Name':'Date'})

# %%
df
# Out:
#           Date      Nagrik   Sagarmatha secutities  Malla & Malla   \
# 0   2021-08-26  29466792.80           7.813524e+07    1.372020e+08
# 1   2021-08-25  78449653.10           9.223734e+07    1.217012e+08
# 2   2021-08-24  80546958.40           8.068601e+07    2.026929e+08
# 3   2021-08-19  96374907.99           1.338335e+08    2.161489e+08
# 4   2021-08-18  71022317.60           1.235867e+08    2.162260e+08
# ..         ...          ...                    ...             ...
# 115 2021-03-07         0.00           3.009167e+07    6.043691e+07
# 116 2021-03-04         0.00           4.105852e+07    7.669963e+07
# 117 2021-03-03         0.00           4.542035e+07    1.021702e+08
# 118 2021-03-02         0.00           4.487011e+07    7.619039e+07
# 119 2021-03-01         0.00           4.112717e+07    7.104314e+07
#
#      Swarlaxhmi Securities  Sewa Securities  Kalika Swcurities    Ashutosh   \
# 0             2.147620e+08      226819443.6       2.514800e+08  256925624.6
# ...

# %%
df['xyz'][119]
# Out:
# 148738194.0

# %%
df.columns
# Out:
# Index(['Date', 'Nagrik ', 'Sagarmatha secutities', 'Malla & Malla ',
#        'Swarlaxhmi Securities', 'Sewa Securities', 'Kalika Swcurities',
#        'Ashutosh ', 'Investment Management', 'Creative Securities', 'xyz'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Nagrik   Sagarmatha secutities  Malla & Malla   \
# count  1.200000e+02           1.200000e+02    1.200000e+02
# mean   4.039754e+07           6.626755e+07    1.167092e+08
# std    2.971544e+07           3.368422e+07    5.018523e+07
# min    0.000000e+00           1.498027e+07    4.299528e+07
# 25%    1.633989e+07           4.028162e+07    7.657232e+07
# 50%    3.880240e+07           6.056386e+07    9.967293e+07
# 75%    6.068734e+07           8.902661e+07    1.553648e+08
# max    1.265628e+08           1.553960e+08    2.559096e+08
#
#        Swarlaxhmi Securities  Sewa Securities  Kalika Swcurities  \
# count           1.200000e+02     1.200000e+02       1.200000e+02
# mean            1.370682e+08     1.925357e+08       1.827400e+08
# std             6.720229e+07     9.669556e+07       9.544726e+07
# min             4.551520e+07     2.240265e+07       1.100107e+07
# 25%             8.889003e+07     1.173965e+08       1.091974e+08
# ...

# %%
df['xyz'].max()
# Out:
# 3022499718.8

# %%
df['xyz'].min()
# Out:
# 0.0

# %%
xi = df['Date']
a2= df['Nagrik ']
a3 = df['Sagarmatha secutities']
a4 = df['Malla & Malla ']
a5 = df['Swarlaxhmi Securities']
a6 = df['Sewa Securities']
a7 = df['Kalika Swcurities']
a8 = df['Ashutosh ']
a9 = df['Investment Management']
a10 = df['Creative Securities']
a11 = df['xyz']

# %%
colors = ['#1f77b4',
          '#ff7f0e',
          '#2ca02c',
          '#d62728',
          '#9467bd',
          '#8c564b',
          '#e377c2',
          '#7f7f7f',
          '#bcbd22',
          '#17becf',
          '#1a55FF']

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,20)

# %%
# create an index for each tick position

#plt.ylim(0.8,1.4)

# plot the index for the x-values
plt.plot(xi, a2, marker='o', linestyle='--', color='#1f77b4', label='Nagrik')
plt.plot(xi, a3, marker='o', linestyle='--', color='#ff7f0e', label='Sagarmatha')
plt.plot(xi, a4, marker='o', linestyle='--', color='#2ca02c', label='Malla')
plt.plot(xi, a5, marker='o', linestyle='--', color='#d62728', label='Swarlaxhmi')
plt.plot(xi, a6, marker='o', linestyle='--', color='#9467bd', label='Sewa')
plt.plot(xi, a7, marker='o', linestyle='--', color='#8c564b', label='Kalika')
plt.plot(xi, a8, marker='o', linestyle='--', color='#e377c2', label='Ashutosh')
plt.plot(xi, a9, marker='o', linestyle='--', color='#7f7f7f', label='Investment')
plt.plot(xi, a10, marker='o', linestyle='--', color='#bcbd22', label='Creative')
plt.plot(xi, a11, marker='o', linestyle='--', color='#17becf', label='xyz')
plt.xlabel('Date')
plt.ylabel('Transaction') 
#plt.xticks(xi, x)
plt.title('Investments')
plt.legend() 
plt.show()

# %%
plt.xlim([0, 2000000000])
plt.ylim([0, 2000000000])
# Out:
# (0.0, 2000000000.0)
